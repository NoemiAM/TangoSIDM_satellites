# %% [markdown]
# # Notebook to plot relation between orbital and structural properties of satellites

# %%
import matplotlib
import numpy as np
from satellite_properties_plot_utils import *

# %%
DATA_PATH = "../data/TangoSIDM/"

IDs = {
    "SigmaConstant00": "CDM",
    "SigmaConstant01": "SigmaConstant01",
    "SigmaConstant10": "SigmaConstant10",
    "SigmaVelDep20Anisotropic": "SigmaVel20",
    "SigmaVelDep60Anisotropic": "SigmaVel60", 
    "SigmaVelDep100Anisotropic": "SigmaVel100",
}

# %% [markdown]
# # Density at 150pc

# %%
# Color coded by accretion redshift
plot_density_150pc("accretion", print_correlation=True)
# Out:
# Plotting density at 150pc versus pericenter distance with accretion colorbar!
# CDM
# Pearson's r: (array([0.04090908871659026], dtype=object), 0.39799717241441224)
# Spearman's rho: SpearmanrResult(correlation=-0.1669599038214557, pvalue=0.00051575011905038)
#
#
# SigmaConstant01
# Pearson's r: (-0.07407329442073729, 0.13240653947157716)
# Spearman's rho: SpearmanrResult(correlation=-0.13530225756167105, pvalue=0.0058270145101708085)
#
#
# SigmaConstant10
# Pearson's r: (-0.06418956814016219, 0.2463419585777864)
# Spearman's rho: SpearmanrResult(correlation=0.050664455781503255, pvalue=0.3603717930965804)
#
#
# SigmaVel20
# Pearson's r: (-0.056860624717238836, 0.25655481753067666)
# Spearman's rho: SpearmanrResult(correlation=-0.06752929705810662, pvalue=0.1776910878107848)
#
#
# SigmaVel60
# Pearson's r: (-0.12483959610848969, 0.012352820407368235)
# Spearman's rho: SpearmanrResult(correlation=-0.17513734320914134, pvalue=0.00042597610818163905)
#
#
# SigmaVel100
# ...

# %% [markdown]
# # Circular velocity at fiducial radius

# %%
# Color coded by accretion redshift
plot_circular_velocity_fiducial_radius("accretion", print_correlation=True)
# Out:
# Plotting circular velocity at fiducial radius versus pericenter distance with accretion colorbar!
# CDM
# Pearson's r: (0.018102064767831702, 0.7098072055978552)
# Spearman's rho: SpearmanrResult(correlation=-0.08844554563786715, pvalue=0.0685228752435532)
#
#
# SigmaConstant01
# Pearson's r: (0.005928753502643882, 0.9046182875863577)
# Spearman's rho: SpearmanrResult(correlation=-0.1301340763389917, pvalue=0.008255643862778642)
#
#
# SigmaConstant10
# Pearson's r: (0.26743577014687614, 9.600105830074188e-07)
# Spearman's rho: SpearmanrResult(correlation=0.16096929917608704, pvalue=0.0035655573884137404)
#
#
# SigmaVel20
# Pearson's r: (0.13890197918568203, 0.005505962302242857)
# Spearman's rho: SpearmanrResult(correlation=-0.014501495565172693, pvalue=0.7730335563021647)
#
#
# SigmaVel60
# Pearson's r: (0.09195479937373266, 0.06617524965703442)
# Spearman's rho: SpearmanrResult(correlation=-0.054490090563066015, pvalue=0.2769488013571039)
#
#
# SigmaVel100
# ...

# %%
# Color coded by peak mass
plot_circular_velocity_fiducial_radius("mass_peak", print_correlation=False)
# Out:
# Plotting circular velocity at fiducial radius versus pericenter distance with mass_peak colorbar!

# %%
# Color coded by bounded mass at z=0
plot_circular_velocity_fiducial_radius("mass_0", print_correlation=False)
# Out:
# Plotting circular velocity at fiducial radius versus pericenter distance with mass_0 colorbar!

# %% [markdown]
# # Circular velocity at 2kpc

# %%
# Color coded by accretion redshift
plot_circular_velocity_2kpc("accretion", print_correlation=True)
# Out:
# Plotting circular velocity at 2kpc versus pericenter distance with accretion colorbar!
# CDM
# Pearson's r: (0.085578272684163, 0.07662692257028202)
# Spearman's rho: SpearmanrResult(correlation=-0.11022241521433343, pvalue=0.02241497534598481)
#
#
# SigmaConstant01
# Pearson's r: (-0.01863114301588413, 0.7054496798045516)
# Spearman's rho: SpearmanrResult(correlation=-0.14859131170067919, pvalue=0.0024367404352574045)
#
#
# SigmaConstant10
# Pearson's r: (0.10088037844212844, 0.06804573004887829)
# Spearman's rho: SpearmanrResult(correlation=0.1274694881753374, pvalue=0.020933335573981894)
#
#
# SigmaVel20
# Pearson's r: (0.05386070520537524, 0.2831497354970841)
# Spearman's rho: SpearmanrResult(correlation=-0.05578893855874544, pvalue=0.2662443734135053)
#
#
# SigmaVel60
# Pearson's r: (0.03101653040744583, 0.5357084288472533)
# Spearman's rho: SpearmanrResult(correlation=-0.10553517041102063, pvalue=0.034631087120875224)
#
#
# SigmaVel100
# ...

# %%
# Color coded by peak mass
plot_circular_velocity_2kpc("mass_peak", print_correlation=False)
# Out:
# Plotting circular velocity at 2kpc versus pericenter distance with mass_peak colorbar!

# %%
# Color coded by bounded mass at z=0
plot_circular_velocity_2kpc("mass_0", print_correlation=False)
# Out:
# Plotting circular velocity at 2kpc versus pericenter distance with mass_0 colorbar!
